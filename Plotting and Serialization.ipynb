# %% [markdown]
# # Plotting

# %%
import pandas as pd

# %%
temp = pd.Series([1, 2, 3, 4, 3, 2, 1], index=list('ABCDEFG'))

# %%
temp
# Out:
# A    1
# B    2
# C    3
# D    4
# E    3
# F    2
# G    1
# dtype: int64

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
temp.plot()

# %%
temp.plot(style='r')

# %%
temp.plot.bar()

# %%
temp.plot.barh()

# %%
temp.plot.box()

# %%
temp.plot.hist()

# %%
ax = temp.plot.kde()
ax.set_xlabel('label for x')
ax.set_ylabel('label for y')

# %%
temp.plot.pie()

# %%
temp.to_csv('file_name.csv')

# %%
# !cat file_name.csv
# Out:
# A,1
# B,2
# C,3
# D,4
# E,3
# F,2
# G,1

# %%
temp.to_csv('file_name.csv', header=True)

# %%
# !cat file_name.csv
# Out:
# ,0
# A,1
# B,2
# C,3
# D,4
# E,3
# F,2
# G,1

# %%
temp.name = "Serie"
temp.to_csv('file_name.csv', header=True, index_label='Index')

# %%
# !cat file_name.csv
# Out:
# Index,Serie
# A,1
# B,2
# C,3
# D,4
# E,3
# F,2
# G,1

# %%
temp2 = pd.Series.from_csv('file_name.csv')

# %%
temp2
# Out:
# Index    Serie
# A            1
# B            2
# C            3
# D            4
# E            3
# F            2
# G            1
# dtype: object

# %%
temp2 = pd.Series.from_csv('file_name.csv', header=0)

# %%
temp2
# Out:
# Index
# A    1
# B    2
# C    3
# D    4
# E    3
# F    2
# G    1
# Name: Serie, dtype: int64

# %%
df = pd.read_csv('file_name.csv')

# %%
df
# Out:
#   Index  Serie
# 0     A      1
# 1     B      2
# 2     C      3
# 3     D      4
# 4     E      3
# 5     F      2
# 6     G      1

# %%
df = pd.read_csv('file_name.csv', index_col=0)

# %%
df
# Out:
#        Serie
# Index
# A          1
# B          2
# C          3
# D          4
# E          3
# F          2
# G          1

# %%
df['Serie'] # the name that we gave before
# Out:
# Index
# A    1
# B    2
# C    3
# D    4
# E    3
# F    2
# G    1
# Name: Serie, dtype: int64
